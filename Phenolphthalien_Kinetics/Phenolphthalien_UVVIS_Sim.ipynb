# %%
import matplotlib.pyplot as plt
import numpy as np
import veloxchem as vlx
from scipy.interpolate import interp1d
import py3Dmol as p3d
from matplotlib import gridspec


# Conversion factor
au2ev = 27.211386

# ==== 1. Define molecule ====
smiles = "O=C1OC(C2=C1C=CC=C2)(C3=CC=C(C=C3)O[H])C4=CC=C(C=C4)O[H]"
phen = vlx.Molecule.read_smiles(smiles)

phen.show()
# Out:
# <div id="3dmolviewer_17685716682525635"  style="position: relative; width: 400px; height: 300px;">
#         <p id="3dmolwarning_17685716682525635" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.3/build/3Dmol-min.js');
# }
#
# var viewer_17685716682525635 = null;
# var warn = document.getElementById("3dmolwarning_17685716682525635");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17685716682525635 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17685716682525635"),{backgroundColor:"white"});
# viewer_17685716682525635.zoomTo();
# 	viewer_17685716682525635.addModel("38\n\nO             -0.291302000000         2.703319000000         2.508253000000\nC             -0.039550000000         1.750986000000         1.724908000000\nO             -1.003728000000         0.930856000000         1.154937000000\nC             -0.394640000000        -0.062061000000         0.311942000000\nC              1.082447000000         0.275536000000         0.431186000000\nC              1.264497000000         1.347847000000         1.274350000000\nC              2.524571000000         1.876088000000         1.547689000000\nC              3.636412000000         1.279796000000         0.931239000000\nC              3.464789000000         0.184665000000         0.060575000000\nC              2.180181000000        -0.323241000000        -0.198891000000\nC             -0.828099000000         0.117462000000        -1.141641000000\nC             -0.622776000000        -0.915199000000        -2.079355000000\nC             -0.978645000000        -0.742529000000        -3.419500000000\nC             -1.529227000000         0.469797000000        -3.850817000000\nC             -1.716850000000         1.509012000000        -2.936339000000\nC             -1.362644000000         1.340745000000        -1.594540000000\nO             -1.888132000000         0.653031000000        -5.184267000000\nC             -0.776491000000        -1.435807000000         0.866503000000\nC              0.120518000000        -2.232236000000         1.611975000000\nC             -0.285247000000        -3.464956000000         2.131752000000\nC             -1.593000000000        -3.915777000000         1.940032000000\nC             -2.502061000000        -3.123163000000         1.230918000000\nC             -2.101377000000        -1.890267000000         0.709702000000\nO             -1.980437000000        -5.147405000000         2.462996000000\nH              2.643969000000         2.722519000000         2.211427000000\nH              4.629276000000         1.665377000000         1.122833000000\nH              4.327038000000        -0.267256000000        -0.412106000000\nH              2.048453000000        -1.164752000000        -0.865288000000\nH             -0.187940000000        -1.858181000000        -1.773135000000\nH             -0.821373000000        -1.550490000000        -4.122649000000\nH             -2.132965000000         2.452161000000        -3.267192000000\nH             -1.504763000000         2.171921000000        -0.916599000000\nH             -1.763185000000        -0.080819000000        -5.871835000000\nH              1.133676000000        -1.910647000000         1.806781000000\nH              0.417603000000        -4.068144000000         2.692461000000\nH             -3.521472000000        -3.458262000000         1.087782000000\nH             -2.827758000000        -1.287365000000         0.178760000000\nH             -2.922416000000        -5.501065000000         2.342578000000\n");
# 	viewer_17685716682525635.setViewStyle({"style": "outline", "width": 0.05});
# 	viewer_17685716682525635.setStyle({"stick": {}, "sphere": {"scale": 0.25}});
# 	viewer_17685716682525635.zoomTo();
# viewer_17685716682525635.render();
# });
# </script>

# %%
basis = vlx.MolecularBasis.read(phen, 'def2-svp')

scf_drv = vlx.ScfRestrictedDriver()
scf_drv.filename = 'mol-opt'
scf_drv.xcfun = 'cam-b3lyp'
scf_drv.dispersion = True
results = scf_drv.compute(phen, basis)

opt_drv = vlx.OptimizationDriver(scf_drv)
opt_drv.filename = 'mol-opt'
opt_drv.keep_files = True
opt_results = opt_drv.compute(phen, basis, results)
# Out:
#
#                                             Self Consistent Field Driver Setup
#                                            ====================================
#
#                    Wave Function Model             : Spin-Restricted Kohn-Sham
#                    Initial Guess Model             : Superposition of Atomic Densities
#                    Convergence Accelerator         : Two Level Direct Inversion of Iterative Subspace
#                    Max. Number of Iterations       : 50
#                    Max. Number of Error Vectors    : 10
#                    Convergence Threshold           : 1.0e-06
#                    ERI Screening Threshold         : 1.0e-12
#                    Linear Dependence Threshold     : 1.0e-06
#                    Exchange-Correlation Functional : CAM-B3LYP
#                    Molecular Grid Level            : 4
#                    Dispersion Correction           : D4
#
# * Info * Using the CAM-B3LYP functional.
#
#          T. Yanai, D. P. Tew, and N. C. Handy.,  Chem. Phys. Lett. 393, 51 (2004)
#
# * Info * Using the Libxc library (v7.0.0).
#
#          S. Lehtola, C. Steigemann, M. J.T. Oliveira, and M. A.L. Marques.,  SoftwareX 7, 1–5 (2018)
#
# * Info * Using the following algorithm for XC numerical integration.
#
#          J. Kussmann, H. Laqua and C. Ochsenfeld, J. Chem. Theory Comput. 2021, 17, 1512-1521
#
# * Info * Using the D4 dispersion correction.
#
#          E. Caldeweyher, C. Bannwarth, S. Grimme, J. Chem. Phys., 2017, 147, 034112.
#          E. Caldeweyher, S. Ehlert, A. Hansen, H. Neugebauer, S. Spicher, C. Bannwarth, S. Grimme, J. Chem
#          Phys, 2019, 150, 154122.
#
# * Info * Starting Reduced Basis SCF calculation...
# * Info * ...done. SCF energy in reduced basis set: -1063.738084282611 a.u. Time: 4.75 sec.
#
#
#                Iter. |    Kohn-Sham Energy | Energy Change | Gradient Norm | Max. Gradient | Density Change
#                --------------------------------------------------------------------------------------------
#                   1     -1070.157621683663    0.0000000000      0.49071360      0.02210697      0.00000000
#                   2     -1070.167309752447   -0.0096880688      0.42188350      0.01619406      0.44361867
#                   3     -1070.184190658029   -0.0168809056      0.16375265      0.00562421      0.22833900
#                   4     -1070.186595478644   -0.0024048206      0.03567917      0.00105920      0.06761471
#                   5     -1070.186698020283   -0.0001025416      0.01722075      0.00060874      0.01990079
#                   6     -1070.186728738224   -0.0000307179      0.00376247      0.00007784      0.00826790
#                   7     -1070.186730405340   -0.0000016671      0.00136382      0.00002517      0.00261692
#                   8     -1070.186730635924   -0.0000002306      0.00046356      0.00001037      0.00076917
#                   9     -1070.186730664443   -0.0000000285      0.00024535      0.00000592      0.00035015
#                  10     -1070.186730671837   -0.0000000074      0.00005499      0.00000131      0.00013574
#                  11     -1070.186730672251   -0.0000000004      0.00003346      0.00000058      0.00003905
#                  12     -1070.186730672402   -0.0000000002      0.00000817      0.00000020      0.00001826
#                  13     -1070.186730672412   -0.0000000000      0.00000373      0.00000007      0.00000615
#                  14     -1070.186730672411    0.0000000000      0.00000116      0.00000003      0.00000259
#                  15     -1070.186730672415   -0.0000000000      0.00000057      0.00000002      0.00000091
#
# * Info * Checkpoint written to file: mol-opt_scf.h5
#
# * Info * SCF results written to file: mol-opt.h5
#
#                *** SCF converged in 15 iterations. Time: 168.29 sec.
#
#                Spin-Restricted Kohn-Sham:
#                --------------------------
#                Total Energy                       :    -1070.1867306724 a.u.
#                Electronic Energy                  :    -3011.9855467321 a.u.
#                Nuclear Repulsion Energy           :     1941.8505961252 a.u.
#                D4 Dispersion Correction           :       -0.0517800656 a.u.
#                ------------------------------------
#                Gradient Norm                      :        0.0000005707 a.u.
#
#
#                Ground State Information
#                ------------------------
#                Charge of Molecule            :  0.0
#                Multiplicity (2S+1)           :  1
#                Magnetic Quantum Number (M_S) :  0.0
#
#
#                                                 Optimization Driver Setup
#                                                ===========================
#
#                                      Coordinate System       :    TRIC
#                                      Constraints             :    No
#                                      Max. Number of Steps    :    300
#                                      Transition State        :    No
#                                      IRC                     :    No
#                                      Hessian                 :    never
#
# * Info * Using geomeTRIC for geometry optimization.
#
#          L.-P. Wang and C.C. Song, J. Chem. Phys. 2016, 144, 214108
#
# * Info * Computing energy and gradient...
#
#                                             Self Consistent Field Driver Setup
#                                            ====================================
#
#                    Wave Function Model             : Spin-Restricted Kohn-Sham
#                    Initial Guess Model             : Restart from Checkpoint
#                    Convergence Accelerator         : Direct Inversion of Iterative Subspace
#                    Max. Number of Iterations       : 50
#                    Max. Number of Error Vectors    : 10
#                    Convergence Threshold           : 1.0e-06
#                    ERI Screening Threshold         : 1.0e-12
#                    Linear Dependence Threshold     : 1.0e-06
#                    Exchange-Correlation Functional : CAM-B3LYP
#                    Molecular Grid Level            : 4
#                    Dispersion Correction           : D4
#
# * Info * Using the CAM-B3LYP functional.
#
#          T. Yanai, D. P. Tew, and N. C. Handy.,  Chem. Phys. Lett. 393, 51 (2004)
#
# * Info * Using the Libxc library (v7.0.0).
#
#          S. Lehtola, C. Steigemann, M. J.T. Oliveira, and M. A.L. Marques.,  SoftwareX 7, 1–5 (2018)
#
# * Info * Using the following algorithm for XC numerical integration.
#
#          J. Kussmann, H. Laqua and C. Ochsenfeld, J. Chem. Theory Comput. 2021, 17, 1512-1521
#
# * Info * Using the D4 dispersion correction.
#
#          E. Caldeweyher, C. Bannwarth, S. Grimme, J. Chem. Phys., 2017, 147, 034112.
#          E. Caldeweyher, S. Ehlert, A. Hansen, H. Neugebauer, S. Spicher, C. Bannwarth, S. Grimme, J. Chem
#          Phys, 2019, 150, 154122.
#
# * Info * Restarting from checkpoint file: mol-opt_scf.h5
#
#
#                Iter. |    Kohn-Sham Energy | Energy Change | Gradient Norm | Max. Gradient | Density Change
#                --------------------------------------------------------------------------------------------
#                   1     -1070.186730672415    0.0000000000      0.00000057      0.00000002      0.00000000
#
# * Info * Checkpoint written to file: mol-opt_scf.h5
#
# * Info * SCF results written to file: mol-opt.h5
#
#                *** SCF converged in 1 iterations. Time: 11.21 sec.
#
#                Spin-Restricted Kohn-Sham:
#                --------------------------
#                Total Energy                       :    -1070.1867306724 a.u.
#                Electronic Energy                  :    -3011.9855467321 a.u.
#                Nuclear Repulsion Energy           :     1941.8505961252 a.u.
#                D4 Dispersion Correction           :       -0.0517800656 a.u.
#                ------------------------------------
#                Gradient Norm                      :        0.0000005707 a.u.
#
#
#                Ground State Information
#                ------------------------
#                Charge of Molecule            :  0.0
#                Multiplicity (2S+1)           :  1
#                Magnetic Quantum Number (M_S) :  0.0
#
#
#                                                    SCF Gradient Driver
#                                                   =====================
#
#                           Gradient Type                   : Analytical
#
#                                               Molecular Geometry (Angstroms)
#                                              --------------------------------
#
#                           Atom         Coordinate X          Coordinate Y          Coordinate Z
#
#                            O          -0.291302000000        2.703319000000        2.508253000000
#                            C          -0.039550000000        1.750986000000        1.724908000000
#                            O          -1.003728000000        0.930856000000        1.154937000000
#                            C          -0.394640000000       -0.062061000000        0.311942000000
#                            C           1.082447000000        0.275536000000        0.431186000000
#                            C           1.264497000000        1.347847000000        1.274350000000
#                            C           2.524571000000        1.876088000000        1.547689000000
#                            C           3.636412000000        1.279796000000        0.931239000000
#                            C           3.464789000000        0.184665000000        0.060575000000
#                            C           2.180181000000       -0.323241000000       -0.198891000000
#                            C          -0.828099000000        0.117462000000       -1.141641000000
#                            C          -0.622776000000       -0.915199000000       -2.079355000000
#                            C          -0.978645000000       -0.742529000000       -3.419500000000
#                            C          -1.529227000000        0.469797000000       -3.850817000000
#                            C          -1.716850000000        1.509012000000       -2.936339000000
#                            C          -1.362644000000        1.340745000000       -1.594540000000
#                            O          -1.888132000000        0.653031000000       -5.184267000000
#                            C          -0.776491000000       -1.435807000000        0.866503000000
#                            C           0.120518000000       -2.232236000000        1.611975000000
#                            C          -0.285247000000       -3.464956000000        2.131752000000
#                            C          -1.593000000000       -3.915777000000        1.940032000000
#                            C          -2.502061000000       -3.123163000000        1.230918000000
#                            C          -2.101377000000       -1.890267000000        0.709702000000
#                            O          -1.980437000000       -5.147405000000        2.462996000000
#                            H           2.643969000000        2.722519000000        2.211427000000
#                            H           4.629276000000        1.665377000000        1.122833000000
#                            H           4.327038000000       -0.267256000000       -0.412106000000
#                            H           2.048453000000       -1.164752000000       -0.865288000000
#                            H          -0.187940000000       -1.858181000000       -1.773135000000
#                            H          -0.821373000000       -1.550490000000       -4.122649000000
#                            H          -2.132965000000        2.452161000000       -3.267192000000
#                            H          -1.504763000000        2.171921000000       -0.916599000000
#                            H          -1.763185000000       -0.080819000000       -5.871835000000
#                            H           1.133676000000       -1.910647000000        1.806781000000
#                            H           0.417603000000       -4.068144000000        2.692461000000
#                            H          -3.521472000000       -3.458262000000        1.087782000000
#                            H          -2.827758000000       -1.287365000000        0.178760000000
#                            H          -2.922416000000       -5.501065000000        2.342578000000
#
#                                             Analytical Gradient (Hartree/Bohr)
#                                            ------------------------------------
#
#                           Atom           Gradient X            Gradient Y            Gradient Z
#
#                            O          -0.008051264977        0.071018427984        0.057469471419
#                            C           0.044516918828       -0.070262634729       -0.061106386566
#                            O          -0.016772084547       -0.022177078239       -0.010699607594
#                            C          -0.006380888835        0.005031689199        0.000122722347
#                            C          -0.014665597488        0.017172194574        0.013393919583
#                            C          -0.012156432301        0.009371077306        0.008958206080
#                            C          -0.010078196961        0.009201567867        0.009041362263
#                            C           0.018374367053        0.003328476437        0.000435836853
#                            C           0.018827920300       -0.006418451609       -0.007598229455
#                            C          -0.005576194337       -0.010324124627       -0.009028386705
#                            C           0.003834892090       -0.005024736623        0.007615580479
#                            C           0.007808855185       -0.016303835263        0.000854075348
#                            C          -0.001158294971       -0.008344678479       -0.013384269924
#                            C           0.001261359376        0.017023224004        0.033752946704
#                            C          -0.003130980371        0.005257305846       -0.002163600930
#                            C          -0.003888260874        0.017462187931        0.009654396951
#                            O          -0.001962770013        0.007250725528        0.002578673582
#                            C          -0.001031352631        0.005350763374       -0.006587921830
#                            C           0.021893463215        0.002343095309        0.007098644957
#                            C           0.003726358048       -0.003226108487        0.002332344179
#                            C           0.028501075309        0.024873282517       -0.003658660872
#                            C          -0.012001290210       -0.011416658375        0.001137764788
#                            C          -0.012944645219        0.009205561334       -0.006709576578
#                            O           0.006912287549       -0.000786463280        0.003157038357
#                            H           0.001325060223       -0.004875469490       -0.004129218929
#                            H          -0.005941266099       -0.002329342396       -0.001143471882
#                            H          -0.005243612284        0.002822518228        0.003025060685
#                            H           0.000485065685        0.004884590573        0.004528087691
#                            H          -0.000813144368        0.005533206591       -0.003311022401
#                            H          -0.000650675293        0.004528463590        0.005161993948
#                            H           0.002423048020       -0.004167881156        0.003863340915
#                            H           0.001390308936       -0.002350900084       -0.005886473916
#                            H          -0.001406143994       -0.022113634914       -0.044437912394
#                            H          -0.006060315710       -0.003434144490        0.000998107960
#                            H          -0.002049039700        0.004740562730       -0.003391599467
#                            H           0.006312745083        0.002799278198        0.000146728870
#                            H           0.002273517919       -0.004088588415        0.003851751139
#                            H          -0.037990097456       -0.031554892225        0.004042098763
#
#                                   *** Time spent in gradient calculation: 245.77 sec ***
#
# * Info *   Energy   : -1070.1867306724 a.u.
# * Info *   Gradient : 2.950808e-02 a.u. (RMS)
# * Info *              1.032114e-01 a.u. (Max)
# * Info *   Time     : 257.62 sec
#
# * Info * Computing energy and gradient...
#
#                                             Self Consistent Field Driver Setup
#                                            ====================================
#
#                    Wave Function Model             : Spin-Restricted Kohn-Sham
#                    Initial Guess Model             : Restart from Checkpoint
#                    Convergence Accelerator         : Direct Inversion of Iterative Subspace
#                    Max. Number of Iterations       : 50
#                    Max. Number of Error Vectors    : 10
#                    Convergence Threshold           : 1.0e-06
#                    ERI Screening Threshold         : 1.0e-12
#                    Linear Dependence Threshold     : 1.0e-06
#                    Exchange-Correlation Functional : CAM-B3LYP
#                    Molecular Grid Level            : 4
#                    Dispersion Correction           : D4
#
# * Info * Using the CAM-B3LYP functional.
#
#          T. Yanai, D. P. Tew, and N. C. Handy.,  Chem. Phys. Lett. 393, 51 (2004)
#
# * Info * Using the Libxc library (v7.0.0).
#
#          S. Lehtola, C. Steigemann, M. J.T. Oliveira, and M. A.L. Marques.,  SoftwareX 7, 1–5 (2018)
#
# * Info * Using the following algorithm for XC numerical integration.
#
#          J. Kussmann, H. Laqua and C. Ochsenfeld, J. Chem. Theory Comput. 2021, 17, 1512-1521
#
# * Info * Using the D4 dispersion correction.
#
#          E. Caldeweyher, C. Bannwarth, S. Grimme, J. Chem. Phys., 2017, 147, 034112.
#          E. Caldeweyher, S. Ehlert, A. Hansen, H. Neugebauer, S. Spicher, C. Bannwarth, S. Grimme, J. Chem
#          Phys, 2019, 150, 154122.
#
# * Info * Restarting from checkpoint file: mol-opt_scf.h5
#
#
#                Iter. |    Kohn-Sham Energy | Energy Change | Gradient Norm | Max. Gradient | Density Change
#                --------------------------------------------------------------------------------------------
#                   
#
#                                   *** Time spent in gradient calculation: 255.55 sec ***
#
# * Info *   Energy   : -1070.2157696101 a.u.
# * Info *   Gradient : 2.807215e-05 a.u. (RMS)
# * Info *              7.022715e-05 a.u. (Max)
# * Info *   Time     : 365.21 sec
#
# * Info * Geometry optimization completed.
#
#                                                 Final Geometry (Angstroms)
#                                                ============================
#
#                           Atom         Coordinate X          Coordinate Y          Coordinate Z
#
#                            O          -0.432369010220        2.578497337812        2.497176128317
#                            C          -0.101387547498        1.718112296718        1.738253678999
#                            O          -0.987916138676        0.922960775302        1.085469927212
#                            C          -0.343811545783       -0.080886172247        0.268530890202
#                            C           1.127335758176        0.261639709674        0.407327085350
#                            C           1.252593006898        1.313717084346        1.296362700933
#                            C           2.484582692720        1.863353694682        1.628431891316
#                            C           3.614442166965        1.319059487561        1.028615133183
#                            C           3.493481684081        0.263158873043        0.116980160113
#                            C           2.250515841150       -0.275669540135       -0.208639722970
#                            C          -0.801344736441        0.089257373410       -1.173341046004
#                            C          -0.666582372032       -0.959039396192       -2.082060791599
#                            C          -1.009181326193       -0.794058486985       -3.419535156387
#                            C          -1.504526197596        0.430625773111       -3.868466757747
#                            C          -1.651851311852        1.482727918240       -2.963074477588
#                            C          -1.299568649162        1.310027378627       -1.632180774328
#                            O          -1.860140393397        0.646197124815       -5.154593365359
#                            C          -0.728640424229       -1.437374307693        0.840022619369
#                            C           0.183511344846       -2.320602243807        1.415255527543
#                            C          -0.232655753863       -3.533837195676        1.952637427378
#                            C          -1.582595697286       -3.877886483834        1.934386775434
#                            C          -2.508565652934       -2.994232151526        1.371371520226
#                            C          -2.080143349832       -1.791678937990        0.831292358660
#                            O          -1.944286766100       -5.064796502558        2.468015457428
#                            H           2.544120434153        2.695824570511        2.331807588414
#                            H           4.603219198019        1.719903264057        1.259499922744
#                            H           4.392307654570       -0.142419767547       -0.352416914287
#                            H           2.168122157877       -1.089678649923       -0.930782841529
#                            H          -0.300435284300       -1.929596842503       -1.742147693174
#                            H          -0.900584160096       -1.627668156104       -4.119194289568
#                            H          -2.049684125499        2.432074923171       -3.324262229631
#                            H          -1.427637243946        2.135073306418       -0.931433450406
#                            H          -1.713879059655       -0.154141574311       -5.672300950624
#                            H           1.242793229604       -2.066530417790        1.453935285482
#                            H           0.479618943445       -4.228023279689        2.400400618190
#                            H          -3.570994462307       -3.253887893712        1.359448114830
#                            H          -2.809667186206       -1.106901139187        0.395506293371
#                            H          -2.900786489837       -5.172468088777        2.406988182742
#
#
#                                              Summary of Geometry Optimization
#                                             ==================================
#
#                   Opt.Step       Energy (a.u.)       Energy Change (a.u.)       Displacement (RMS, Max)
#                   -------------------------------------------------------------------------------------
#                       0       -1070.186730672415        0.000000000000         0.000e+00      0.000e+00
#                       1       -1070.211854424290       -0.025123751875         1.031e-01      3.040e-01
#                       2       -1070.210980729653        0.000873694637         6.026e-02      1.281e-01
#                       3       -1070.215352882036       -0.004372152383         3.109e-02      6.593e-02
#                       4       -1070.215084291374        0.000268590662         2.023e-02      3.885e-02
#                       5       -1070.215639092479       -0.000554801105         1.063e-02      1.950e-02
#                       6       -1070.215576550387        0.000062542092         1.005e-02      2.213e-02
#                       7       -1070.215697861761       -0.000121311374         5.153e-03      1.240e-02
#                       8       -1070.215703865077       -0.000006003316         5.395e-03      1.062e-02
#                       9       -1070.215713901216       -0.000010036138         7.548e-03      1.571e-02
#                      10       -1070.215723277132       -0.000009375917         1.003e-02      2.258e-02
#                      11       -1070.215735710343       -0.000012433211         1.550e-02      3.708e-02
#                      12       -1070.215744493454       -0.000008783111         2.009e-02      4.972e-02
#                      13       -1070.215751860295       -0.000007366841         1.325e-02      3.382e-02
#                      14       -1070.215758680142       -0.000006819847         2.317e-02      6.038e-02
#                      15       -1070.215765823264       -0.000007143122         2.645e-02      6.397e-02
#                      16       -1070.215768500901       -0.000002677637         6.076e-03      1.170e-02
#                      17       -1070.215768794343       -0.000000293441         2.723e-03      6.236e-03
#                      18       -1070.215769397648       -0.000000603305         1.755e-03      4.470e-03
#                      19       -1070.215769610135       -0.000000212488         9.505e-04      1.717e-03
#
#
#                                               Statistical Deviation between
#                                          Optimized Geometry and Initial Geometry
#                                         =========================================
#
#                                Internal Coord.        RMS deviation         Max. deviation
#                                -----------------------------------------------------------
#                                   Bonds               0.021 Angstrom        0.064 Angstrom
#                                   Angles              2.710 degree         11.709 degree
#                                   Dihedrals           2.814 degree         11.515 degree
#
#                                     *** Time spent in Optimization Driver: 7808.97 sec
#
# * Info * Optimization results written to file: mol-opt.h5

# %%
opt_drv.show_convergence(opt_results)
# Out:
# interactive(children=(IntSlider(value=19, description='step', max=19), Output()), _dom_classes=('widget-intera…

# %%
import veloxchem as vlx
import py3Dmol as p3d
from matplotlib import pyplot as plt
import numpy as np
import ipywidgets
import h5py

# %%
def read_xyz_file(file_name):
    """Reads all the configurations from an xyz geometry optimization file."""
    xyz_file = open(file_name, "r")
    data = xyz_file.read()
    xyz_file.close()
    
    xyz_file = open(file_name, "r")
    i = 0
    steps = []
    energies = []
    for line in xyz_file:
        if "Energy" in line:
            steps.append(i)
            i += 1
            parts = line.split()
            energy = float(parts[-1])
            energies.append(energy)
    xyz_file.close()
    
    return data, steps, energies

def read_xyz_index(file_name, index=0):
    """Reads one configuration defined by its index from the xyz optimization file."""
    xyz_file = open(file_name, "r")
    current_index = 0
    data = ""

    # Read the number of atoms from the first line
    line = xyz_file.readline()
    natm = line.split()[0]
    data += line
    for line in xyz_file:
        if index == current_index:
            data += line
            if 'Energy' in line:
                parts = line.split()
                energy = float(parts[-1])
        if natm in line:
            parts = line.split()
            if len(parts) == 1:
                if index == current_index:
                    break
                current_index += 1
    xyz_file.close()
    return data, energy


def return_viewer(file_name, step=0):
    xyz_data_i, energy_i = read_xyz_index(file_name, step)
    
    # Uncomment if you would also like to see the energy plot
    # or comment out if you would like to skip this.
    # plt.figure(figsize=(7,4))
    # plt.plot(steps, energies, 'o--')
    # plt.plot(step, energy_i, 'o', markersize=15)
    # plt.xlabel('Iteration')
    # plt.ylabel('Energy (H)')
    # plt.title("Phenolphthalein optimization")
    # plt.tight_layout(); plt.show()
    
    viewer = p3d.view(width=600, height=300)
    viewer.addModel(xyz_data_i)
    viewer.setViewStyle({"style": "outline", "width": 0.05})
    viewer.setStyle({"stick": {}, "sphere": {"scale": 0.25}})
    viewer.show()

# %%
xyz_file_name = 'mol-opt_optim.xyz'
xyz_data, steps, energies = read_xyz_file(xyz_file_name)

# # Plot the energies
# plt.figure(figsize=(7,4))
# plt.plot(steps, energies,'o--')
# plt.xlabel('Iteration')
# plt.ylabel('Energy (H)')
# plt.title("Phenolphthalein optimization")
# plt.tight_layout(); plt.show()

# and animate the optimization
viewer = p3d.view(width=600, height=300)
viewer.addModelsAsFrames(xyz_data)
viewer.animate({"loop": "forward"})

viewer.setViewStyle({"style": "outline", "width": 0.05})
viewer.setStyle({"stick": {}, "sphere": {"scale": 0.25}})

viewer.show()
# Out:
# <div id="3dmolviewer_17685822081011307"  style="position: relative; width: 600px; height: 300px;">
#         <p id="3dmolwarning_17685822081011307" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.3/build/3Dmol-min.js');
# }
#
# var viewer_17685822081011307 = null;
# var warn = document.getElementById("3dmolwarning_17685822081011307");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17685822081011307 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17685822081011307"),{backgroundColor:"white"});
# viewer_17685822081011307.zoomTo();
# 	viewer_17685822081011307.addModelsAsFrames("38   \nIteration 0 Energy -1070.18673067\nO       -0.2913020000    2.7033190000    2.5082530000\nC       -0.0395500000    1.7509860000    1.7249080000\nO       -1.0037280000    0.9308560000    1.1549370000\nC       -0.3946400000   -0.0620610000    0.3119420000\nC        1.0824470000    0.2755360000    0.4311860000\nC        1.2644970000    1.3478470000    1.2743500000\nC        2.5245710000    1.8760880000    1.5476890000\nC        3.6364120000    1.2797960000    0.9312390000\nC        3.4647890000    0.1846650000    0.0605750000\nC        2.1801810000   -0.3232410000   -0.1988910000\nC       -0.8280990000    0.1174620000   -1.1416410000\nC       -0.6227760000   -0.9151990000   -2.0793550000\nC       -0.9786450000   -0.7425290000   -3.4195000000\nC       -1.5292270000    0.4697970000   -3.8508170000\nC       -1.7168500000    1.5090120000   -2.9363390000\nC       -1.3626440000    1.3407450000   -1.5945400000\nO       -1.8881320000    0.6530310000   -5.1842670000\nC       -0.7764910000   -1.4358070000    0.8665030000\nC        0.1205180000   -2.2322360000    1.6119750000\nC       -0.2852470000   -3.4649560000    2.1317520000\nC       -1.5930000000   -3.9157770000    1.9400320000\nC       -2.5020610000   -3.1231630000    1.2309180000\nC       -2.1013770000   -1.8902670000    0.7097020000\nO       -1.9804370000   -5.1474050000    2.4629960000\nH        2.6439690000    2.7225190000    2.2114270000\nH        4.6292760000    1.6653770000    1.1228330000\nH        4.3270380000   -0.2672560000   -0.4121060000\nH        2.0484530000   -1.1647520000   -0.8652880000\nH       -0.1879400000   -1.8581810000   -1.7731350000\nH       -0.8213730000   -1.5504900000   -4.1226490000\nH       -2.1329650000    2.4521610000   -3.2671920000\nH       -1.5047630000    2.1719210000   -0.9165990000\nH       -1.7631850000   -0.0808190000   -5.
#                   7     -1070.134950339755   -0.0000016671      0.00136382      0.00002517      0.00261692
#                   8     -1070.134950570337   -0.0000002306      0.00046356      0.00001037      0.00076917
#                   9     -1070.134950598858   -0.0000000285      0.00024535      0.00000592      0.00035015
#                  10     -1070.134950606253   -0.0000000074      0.00005499      0.00000131      0.00013574
#                  11     -1070.134950606667   -0.0000000004      0.00003346      0.00000058      0.00003905
#                  12     -1070.134950606814   -0.0000000001      0.00000817      0.00000020      0.00001826
#                  13     -1070.134950606827   -0.0000000000      0.00000373      0.00000007      0.00000615
#                  14     -1070.134950606828   -0.0000000000      0.00000116      0.00000003      0.00000259
#                  15     -1070.134950606829   -0.0000000000      0.00000057      0.00000002      0.00000091
#
#                *** SCF converged in 15 iterations. Time: 177.81 sec.
#
#                Spin-Restricted Kohn-Sham:
#                --------------------------
#                Total Energy                       :    -1070.1349506068 a.u.
#                Electronic Energy                  :    -3011.9855467321 a.u.
#                Nuclear Repulsion Energy           :     1941.8505961252 a.u.
#                ------------------------------------
#                Gradient Norm                      :        0.0000005707 a.u.
#
#
#                Ground State Information
#                ------------------------
#                Charge of Molecule            :  0.0
#                Multiplicity (2S+1)           :  1
#                Magnetic Quantum Number (M_S) :  0.0
#
#
#                                             Linear Response EigenSolver Setup
#                                            ===================================
#
#                                Number of States                : 10
#                                Max. Number of Iterations       : 150
#                                Convergence Threshold           : 1.0e-04
#                                ERI Screening Threshold         : 1.0e-12
#                                Exchange-Correlation Functional : CAM-B3LYP
#                                Molecular Grid Level            : 4
#
# * Info * Using the CAM-B3LYP functional.
#
#          T. Yanai, D. P. Tew, and N. C. Handy.,  Chem. Phys. Lett. 393, 51 (2004)
#
# * Info * Using the Libxc library (v7.0.0).
#
#          S. Lehtola, C. Steigemann, M. J.T. Oliveira, and M. A.L. Marques.,  SoftwareX 7, 1–5 (2018)
#
# * Info * Using the following algorithm for XC numerical integration.
#
#          J. Kussmann, H. Laqua and C. Ochsenfeld, J. Chem. Theory Comput. 2021, 17, 1512-1521
#
# * Info * 10 gerade trial vectors in reduced space
# * Info * 10 ungerade trial vectors in reduced space
#
#                *** Iteration:   1 * Residuals (Max,Min): 4.51e-01 and 1.23e-01
#
# * Info * 20 gerade trial vectors in reduced space
# * Info * 20 ungerade trial vectors in reduced space
#
#                *** Iteration:   2 * Residuals (Max,Min): 1.18e-01 and 4.74e-02
#
# * Info * 30 gerade trial vectors in reduced space
# * Info * 30 ungerade trial vectors in reduced space
#
#                *** Iteration:   3 * Residuals (Max,Min): 1.20e-01 and 2.93e-02
#
# * Info * 40 gerade trial vectors in reduced space
# * Info * 40 ungerade trial vectors in reduced space
#
#                *** Iteration:   4 * Residuals (Max,Min): 6.89e-02 and 2.59e-02
#
# * Info * 50 gerade trial vectors in reduced space
# * Info * 50 ungerade trial vectors in reduced space
#
#                *** Iteration:   5 * Residuals (Max,Min): 8.11e-02 and 8.87e-03
#
# * Info * 60 gerade trial vectors in reduced space
# * Info * 60 ungerade trial vectors in reduced space
#
#                *** Iteration:   6 * Residuals (Max,Min): 7.07e-02 and 3.59e-03
#
# * Info * 70 gerade trial vectors in reduced space
# * Info * 70 ungerade trial vectors in reduced space
#
#                *** Iteration:   7 * Residuals (Max,Min): 3.37e-02 and 1.46e-03
#
# * Info * 80 gerade trial vectors in reduced space
# * Info * 80 ungerade trial vectors in reduced space
#
#                *** Iteration:   8 * Residuals (Max,Min): 1.25e-02 and 4.27e-04
#
# * Info * 90 gerade trial vectors in reduced space
# * Info * 90 ungerade trial vectors in reduced space
#
#                *** Iteration:   9 * Residuals (Max,Min): 4.02e-03 and 1.29e-04
#
# * Info * 100 gerade trial vectors in reduced space
# * Info * 100 ungerade trial vectors in reduced space
#
#                *** Iteration:   10 * Residuals (Max,Min): 1.30e-03 and 3.28e-05
#
# * Info * 105 gerade trial vectors in reduced space
# * Info * 105 ungerade trial vectors in reduced space
#
#                *** Iteration:   11 * Residuals (Max,Min): 6.32e-04 and 2.67e-05
#
# * Info * 109 gerade trial vectors in reduced space
# * Info * 109 ungerade trial vectors in reduced space
#
#                *** Iteration:   12 * Residuals (Max,Min): 3.37e-04 and 2.62e-05
#
# * Info * 111 gerade trial vectors in reduced space
# * Info * 111 ungerade trial vectors in reduced space
#
#                *** Iteration:   13 * Residuals (Max,Min): 1.52e-04 and 2.43e-05
#
# * Info * 112 gerade trial vectors in reduced space
# * Info * 112 ungerade trial vectors in reduced space
#
#                *** Iteration:   14 * Residuals (Max,Min): 6.87e-05 and 1.97e-05
#
#                *** Linear response converged in 14 iterations. Time: 2405.59 sec
#
#
#                Electric Transition Dipole Moments (dipole length, a.u.)
#                --------------------------------------------------------
#                                                 X            Y            Z
#                Excited State    S1:     -0.002992    -0.036020    -0.004816
#                Excited State    S2:      0.232446     0.163210     0.483293
#                Excited State    S3:      0.151581    -0.489247    -0.154045
#                Excited State    S4:     -0.301130    -0.120923    -0.271057
#                Excited State    S5:     -0.201816     0.056322    -0.415260
#                Excited State    S6:      0.106981     0.328496    -0.469885
#                Excited State    S7:     -0.009589     0.198322     0.575784
#                Excited State    S8:     -1.037097     0.213276    -0.380336
#                Excited State    S9:     -0.658533    -0.795601     0.345112
#                Excited State   S10:      0.368343    -0.255311     0.369880
#
#                Electric Transition Dipole Moments (dipole velocity, a.u.)
#                ----------------------------------------------------------
#                                                 X            Y            Z
#                Excited State    S1:     -0.003790    -0.011695    -0.037571
#                Excited State    S2:      0.236006     0.164342     0.487776
#                Excited State    S3:      0.160051    -0.506702    -0.150056
#                Excited State    S4:     -0.312019    -0.122916    -0.281182
#                Excited State    S5:     -0.215191     0.052993    -0.409422
#                Excited State    S6:      0.090981     0.333521    -0.466914
#                Excited State    S7:     -0.011666     0.174283     0.550726
#                Excited State    S8:     -1.014104     0.192711    -0.395417
#                Excited State    S9:     -0.661333    -0.787117     0.339917
#                Excited State   S10:      0.358015    -0.238885     0.358979
#
#                Magnetic Transition Dipole Moments (a.u.)
#                -----------------------------------------
#                                                 X            Y            Z
#                Excited State    S1:     -0.121750     0.282040     0.242749
#                Excited State    S2:     -0.076129    -0.181202     0.314083
#                Excited State    S3:     -0.141358     0.000392     0.094140
#                Excited State    S4:     -0.028006    -0.043359    -0.121262
#                Excited State    S5:     -0.016258    -0.119012     0.010134
#                Excited State    S6:      0.011551     0.058669    -0.106461
#                Excited State    S7:      0.055853     0.110703     0.006711
#                Excited State    S8:     -0.111158    -0.383566     0.232351
#                Excited State    S9:      0.125316    -0.157782     0.008313
#                Excited State   S10:     -0.069225     0.137840    -0.208262
#
#                One-Photon Absorption
#                ---------------------
#                Excited State    S1:      0.16742898 a.u.      4.55597 eV    Osc.Str.    0.0001
#                Excited State    S2:      0.18066007 a.u.      4.91601 eV    Osc.Str.    0.0378
#                Excited State    S3:      0.18747570 a.u.      5.10147 eV    Osc.Str.    0.0358
#                Excited State    S4:      0.18913834 a.u.      5.14672 eV    Osc.Str.    0.0225
#                Excited State    S5:      0.19574075 a.u.      5.32638 eV    Osc.Str.    0.0282
#                Excited State    S6:      0.20248448 a.u.      5.50988 eV    Osc.Str.    0.0459
#                Excited State    S7:      0.20768326 a.u.      5.65135 eV    Osc.Str.    0.0514
#                Excited State    S8:      0.21213056 a.u.      5.77237 eV    Osc.Str.    0.1790
#                Excited State    S9:      0.21592003 a.u.      5.87548 eV    Osc.Str.    0.1707
#                Excited State   S10:      0.22341328 a.u.      6.07939 eV    Osc.Str.    0.0503
#
#                Electronic Circular Dichroism
#                -----------------------------
#                Excited State    S1:     Rot.Str.     -0.011957 a.u.    -5.6371 [10**(-40) cgs]
#                Excited State    S2:     Rot.Str.      0.105456 a.u.    49.7165 [10**(-40) cgs]
#                Excited State    S3:     Rot.Str.     -0.036949 a.u.   -17.4195 [10**(-40) cgs]
#                Excited State    S4:     Rot.Str.      0.048165 a.u.    22.7069 [10**(-40) cgs]
#                Excited State    S5:     Rot.Str.     -0.006957 a.u.    -3.2799 [10**(-40) cgs]
#                Excited State    S6:     Rot.Str.      0.070326 a.u.    33.1548 [10**(-40) cgs]
#                Excited State    S7:     Rot.Str.      0.022338 a.u.    10.5311 [10**(-40) cgs]
#                Excited State    S8:     Rot.Str.     -0.053067 a.u.   -25.0180 [10**(-40) cgs]
#                Excited State    S9:     Rot.Str.      0.044143 a.u.    20.8109 [10**(-40) cgs]
#                Excited State   S10:     Rot.Str.     -0.132473 a.u.   -62.4537 [10**(-40) cgs]
#
#                Character of excitations:
#
#                Excited state 1
#                ---------------
#                HOMO-6   -> LUMO         0.8844
#                HOMO-6   -> LUMO+8       0.2580
#
#                Excited state 2
#                ---------------
#                HOMO     -> LUMO        -0.6381
#                HOMO-4   -> LUMO         0.4854
#                HOMO-1   -> LUMO         0.3647
#                HOMO-5   -> LUMO+1      -0.2731
#
#                Excited state 3
#                ---------------
#                HOMO     -> LUMO+2       0.6858
#                HOMO-1   -> LUMO+4      -0.3141
#                HOMO-2   -> LUMO+5      -0.2442
#                HOMO     -> LUMO+1       0.2273
#                HOMO     -> LUMO+4       0.2237
#                HOMO-1   -> LUMO+1      -0.2133
#                HOMO-3   -> LUMO+5      -0.2082
#
#                Excited state 4
#                ---------------
#                HOMO-1   -> LUMO+2      -0.5657
#                HOMO     -> LUMO+4       0.3931
#                HOMO-1   -> LUMO        -0.3067
#                HOMO-2   -> LUMO+3       0.2662
#                HOMO-3   -> LUMO+3      -0.2614
#                HOMO     -> LUMO        -0.2588
#                HOMO-1   -> LUMO+4       0.2509
#
#                Excited state 5
#                ---------------
#                HOMO     -> LUMO         0.6099
#                HOMO-4   -> LUMO         0.3680
#                HOMO     -> LUMO+1       0.3588
#                HOMO-5   -> LUMO        -0.2279
#                HOMO-1   -> LUMO+2      -0.2181
#                HOMO-5   -> LUMO+1      -0.2080
#                HOMO-1   -> LUMO         0.2043
#
#                Excited state 6
#                ---------------
#                HOMO-1   -> LUMO        -0.6857
#                HOMO-5   -> LUMO        -0.3393
#                HOMO-1   -> LUMO+1      -0.2752
#                HOMO     -> LUMO+1       0.2203
#
#                Excited state 7
#                ---------------
#                HOMO     -> LUMO+1      -0.4925
#                HOMO-4   -> LUMO         0.4276
#                HOMO-1   -> LUMO        -0.3824
#                HOMO-5   -> LUMO         0.2854
#                HOMO     -> LUMO         0.2337
#                HOMO-5   -> LUMO+1      -0.2073
#
#                Excited state 8
#                ---------------
#                HOMO-5   -> LUMO         0.6270
#                HOMO     -> LUMO+1       0.4938
#                HOMO     -> LUMO+5      -0.2845
#                HOMO-2   -> LUMO        -0.2572
#                HOMO-4   -> LUMO         0.2032
#
#                Excited state 9
#                ---------------
#                HOMO-1   -> LUMO+3       0.6144
#                HOMO     -> LUMO+3       0.5507
#                HOMO-3   -> LUMO+2      -0.2277
#                HOMO-2   -> LUMO+2       0.2274
#
#                Excited state 10
#                ----------------
#                HOMO-1   -> LUMO+1       0.7971
#                HOMO     -> LUMO+1       0.3491
#                HOMO     -> LUMO+5       0.2340

# %%
au2ev = 27.211386

# Print results as a table
print("Energy [au]  Osc. str.   TM(x)     TM(y)     TM(z)")
for i in np.arange(len(rsp_results["eigenvalues"])):
    e, os, x, y, z = (
        rsp_results["eigenvalues"][i],
        rsp_results["oscillator_strengths"][i],
        rsp_results["electric_transition_dipoles"][i][0],
        rsp_results["electric_transition_dipoles"][i][1],
        rsp_results["electric_transition_dipoles"][i][2],
    )
    print("   {:.3f}     {:8.5f}  {:8.5f}  {:8.5f}  {:8.5f}".format(1240/(e* au2ev), os, x, y, z))
# Out:
# Energy [au]  Osc. str.   TM(x)     TM(y)     TM(z)
#    272.170      0.00015  -0.00299  -0.03602  -0.00482
#    252.237      0.03785   0.23245   0.16321   0.48329
#    243.067      0.03575   0.15158  -0.48925  -0.15405
#    240.930      0.02254  -0.30113  -0.12092  -0.27106
#    232.804      0.02823  -0.20182   0.05632  -0.41526
#    225.050      0.04592   0.10698   0.32850  -0.46988
#    219.417      0.05136  -0.00959   0.19832   0.57578
#    214.817      0.17900  -1.03710   0.21328  -0.38034
#    211.046      0.17068  -0.65853  -0.79560   0.34511
#    203.968      0.05029   0.36834  -0.25531   0.36988

# %%
205nm, 229nm, 276nm

# %%
rsp_drv.plot(rsp_results, plot_type="uv")

# %%
viewer = vlx.OrbitalViewer()
viewer.plot(phen, basis, scf_drv.mol_orbs)
# Out:
#
#                Iter. |    Kohn-Sham Energy | Energy Change | Gradient Norm | Max. Gradient | Density Change
#                --------------------------------------------------------------------------------------------
# Output()
# Dropdown(description='Orbital:', index=82, options=(('  1 occ=2.000 ene=-19.250  (alpha HOMO-82)', 0), ('  2 o…
